# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

# %%
digits=load_digits()
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
plt.gray()
for i in range(0,5):
    plt.matshow(digits.images[i])

# %%
digits.data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
from sklearn.linear_model import LogisticRegression
reg=LogisticRegression()
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.2)

# %%
reg.fit(X_train,y_train)
# Out:
# C:\Users\Admin\pythonlab\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predicted=reg.predict(X_test)
predicted
# Out:
# array([1, 5, 1, 2, 7, 6, 2, 8, 5, 5, 2, 9, 9, 3, 0, 1, 5, 8, 3, 1, 4, 4,
#        8, 1, 1, 8, 3, 2, 1, 5, 4, 7, 4, 5, 8, 1, 9, 4, 7, 7, 1, 9, 0, 5,
#        8, 9, 5, 1, 5, 9, 4, 8, 7, 6, 3, 1, 1, 5, 9, 4, 5, 9, 7, 1, 9, 7,
#        3, 5, 9, 0, 0, 2, 2, 9, 3, 9, 2, 8, 4, 0, 0, 5, 8, 3, 6, 6, 1, 7,
#        7, 8, 6, 2, 7, 5, 3, 1, 6, 7, 8, 0, 6, 3, 0, 0, 1, 1, 2, 7, 6, 5,
#        8, 1, 5, 1, 5, 3, 2, 3, 4, 2, 1, 3, 1, 7, 7, 2, 8, 0, 6, 0, 5, 3,
#        1, 6, 7, 7, 5, 1, 4, 9, 5, 1, 3, 0, 4, 7, 2, 0, 5, 2, 1, 8, 6, 7,
#        6, 7, 2, 0, 5, 5, 3, 2, 5, 5, 1, 1, 4, 7, 3, 6, 5, 1, 5, 4, 0, 4,
#        1, 6, 1, 4, 3, 5, 0, 0, 3, 2, 3, 6, 2, 4, 5, 1, 2, 9, 5, 7, 2, 7,
#        9, 6, 5, 3, 0, 2, 2, 7, 8, 1, 2, 0, 3, 9, 0, 0, 9, 6, 6, 5, 9, 8,
#        9, 0, 8, 6, 9, 7, 9, 9, 4, 8, 9, 1, 9, 3, 9, 6, 9, 1, 3, 2, 1, 2,
#        2, 8, 6, 1, 9, 2, 2, 9, 0, 5, 3, 1, 2, 9, 7, 6, 3, 2, 4, 1, 1, 7,
#        8, 0, 0, 3, 0, 1, 3, 9, 3, 0, 2, 7, 4, 0, 8, 9, 6, 7, 1, 9, 8, 8,
#        7, 6, 8, 2, 9, 7, 2, 8, 6, 3, 3, 4, 5, 2, 0, 8, 3, 0, 6, 2, 6, 8,
#        2, 4, 8, 2, 2, 6, 7, 1, 1, 1, 9, 9, 7, 3, 4, 5, 1, 4, 8, 2, 9, 4,
#        9, 6, 4, 4, 3, 4, 2, 9, 5, 2, 4, 5, 8, 6, 8, 0, 5, 9, 6, 7, 3, 1,
#        2, 6, 3, 8, 2, 6, 2, 3])

# %%
reg.score(X_train,y_train)
# Out:
# 1.0

# %%
reg.score(X_test,y_test)
# Out:
# 0.9611111111111111

# %%
reg.predict([digits.data[0]])
# Out:
# array([0])

# %%
reg.predict(digits.data[0:5])
# Out:
# array([0, 1, 2, 3, 4])

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(predicted,y_test)

# %%
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm ,annot=True)
plt.xlabel('predicted')
plt.ylabel('truth')
# Out:
# Text(95.72222222222221, 0.5, 'truth')
